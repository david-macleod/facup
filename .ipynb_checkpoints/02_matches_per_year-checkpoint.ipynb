# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')

# %%
fac = pd.read_csv('facup_v2.csv')

fac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137076 entries, 0 to 137075
# Data columns (total 15 columns):
# home_team     137076 non-null object
# away_team     137076 non-null object
# home_score    137076 non-null int64
# away_score    137076 non-null int64
# round         137076 non-null object
# year          137076 non-null int64
# qualifier     137076 non-null bool
# replay        137076 non-null bool
# stage         137076 non-null int64
# date          137076 non-null object
# match_id      137076 non-null float64
# round_id      137076 non-null float64
# year_id       137076 non-null int64
# team          137076 non-null object
# home          137076 non-null bool
# dtypes: bool(3), float64(2), int64(5), object(5)
# memory usage: 14.0+ MB

# %%
matches_per_year = fac.groupby('year')['match_id'].nunique().reindex(range(1872,2016))

# %%
# %matplotlib inline

matplotlib.style.use('ggplot')

ax = matches_per_year.plot(kind='bar', 
                         figsize=(13,5), 
                         width=1, 
                         color='steelblue')

ticks = ax.xaxis.get_ticklocs()
ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
ax.xaxis.set_ticks(ticks[::5])
ax.xaxis.set_ticklabels(ticklabels[::5])

plt.show()

# %%
#no. of qualifiers/non qualifiers per year

q = fac[fac['qualifier'] == True] 
nq = fac[fac['qualifier'] == False]

q.match_id.size + nq.match_id.size #checking that all rows are accounted for
# Out:
# 137076

# %%
q_per_year = q.groupby('year')['match_id'].nunique().reindex(range(1872,2016)) * -1
nq_per_year = nq.groupby('year')['match_id'].nunique().reindex(range(1872,2016))

# %%
q_per_year.plot(kind='bar', 
                 figsize=(13,5), 
                 width=1, 
                 color='lightsteelblue')

ax = plt.gca()

nq_per_year.plot(kind='bar', 
                 width=1, 
                 color='steelblue',
                 ax = ax, 
                 ylim = (-800, 300))

ticks = ax.xaxis.get_ticklocs()
ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
ax.xaxis.set_ticks(ticks[::5])
ax.xaxis.set_ticklabels(ticklabels[::5])
ax.legend().set_visible(False)

plt.show()

# %% [markdown]
# ### Why do qualifiers start in 1889?
#
# According to Wikipedia:
# >"The FA Cup, from this season onwards, began to incorporate a series of qualifying rounds in order to determine qualifiers for the actual Cup competition itself. The qualifying rounds were made up of amateur teams, semi-professional teams, and professional sides not yet associated with the Football League."

# %% [markdown]
# ### Why are there so many matches in 1946?

# %%
fac[(fac.year == 1946) & (fac.qualifier == False) & (fac.replay == False) & (fac.home == True)]['round'].value_counts()
# Out:
# First Round Proper     34
# Third Round Proper     32
# Second Round Proper    17
# Fourth Round Proper    16
# Fifth Round Proper      8
# Sixth Round Proper      4
# Semi-Final              2
# Final                   1
# Name: round, dtype: int64

# %%
fac[(fac.year == 1947) & (fac.qualifier == False) & (fac.replay == False) & (fac.home == True)]['round'].value_counts()
# Out:
# First Round Proper     34
# Third Round Proper     32
# Second Round Proper    17
# Fourth Round Proper    16
# Fifth Round Proper      8
# Sixth Round Proper      4
# Semi-Final              2
# Final                   1
# Name: round, dtype: int64

# %% [markdown]
# Both 1946 and 1947 have the same number of matches (excluding replays) so extra matches must be due to replays?

# %%
fac[(fac.year == 1946) & (fac.qualifier == False) & (fac.replay == True) & (fac.home == True)]['round'].value_counts()
# Out:
# First Round Proper     34
# Third Round Proper     34
# Second Round Proper    17
# Fourth Round Proper    17
# Fifth Round Proper      8
# Sixth Round Proper      4
# Semi-Final              1
# Name: round, dtype: int64

# %% [markdown]
# We can see that every match had at least one replay in 1946! According to Wikipedia:
#
# >"For the only time in the history of the competition, all matches from the First Round Proper up to and including the Sixth Round Proper were played over two legs ... These changes were made in order to give clubs additional revenue, as the Football League would not resume normal play until the autumn of 1946."

# %%
#creating new column 'stage_r that 'hangs' stages off final (=14) rather than initial round

def set_stages(grp):
    stages = grp['stage'].max()
    grp['stage_r'] = grp['stage'] - stages + 14
    return grp

fac2 = fac.groupby(['year']).apply(set_stages)

fac2.to_csv('facup_v3.csv', index = False)

# %%
nq2 = fac2[fac2['qualifier'] == False]

# %%
matches_per_stage = nq2.groupby(['year', 'stage_r'])['match_id'].nunique().unstack().reindex(range(1872,2016))

matches_per_stage.head()
# Out:
# stage_r  7   8   9   10  11  12  13  14
# year
# 1872    NaN NaN NaN   8   6   3   4   1
# 1873    NaN NaN   9   7   4   3   2   1
# 1874    NaN NaN NaN  16   9   5   2   1
# 1875    NaN NaN NaN  19   8   5   3   2
# 1876    NaN NaN NaN  17   8   4   2   2

# %%
ax = matches_per_stage.plot(kind='bar', 
                       figsize=(13,5), 
                       width=1, 
                       stacked=True, 
                       colormap = 'Blues_r')

ticks = ax.xaxis.get_ticklocs()
ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
ax.xaxis.set_ticks(ticks[::5])
ax.xaxis.set_ticklabels(ticklabels[::5])
ax.legend().set_visible(False)

plt.show()

# %%
matches_per_stage.loc[1903:1905]
# Out:
# stage_r  7   8   9   10  11  12  13  14
# year
# 1903    NaN NaN  14  21   9   4   2   1
# 1904    NaN NaN  17  20  10   6   2   1
# 1905    NaN  15 NaN  25  10   5   3   1

# %%
fac2[(fac2.year == 1905)].groupby('round').first().sort_values('stage')
# Out:
#                                    home_team            away_team  home_score  \
# round
# Extra Preliminary Round     Thornhill United       Rotherham Town           1
# Preliminary Round             Stanley United        Leadgate Park           1
# First Qualifying Round                Druids      Oswestry United           3
# Second Qualifying Round          Kensal Rise        Civil Service           4
# Third Qualifying Round   Wellingborough Town       Kettering Town           1
# Fourth Qualifying Round     Stockport County              Glossop           1
# Fifth Qualifying Round       Bishop Auckland  Sunderland West End           1
# Intermediate Round         Manchester United               Fulham           0
# Sixth Qualifying Round     Burslem Port Vale             Barnsley           1
# First Round Proper                    Fulham              Reading           1
# Second Round Proper        Preston North End         Bristol City           1
# Third Round Proper       Sheffield Wednesday    Preston North End           3
# Semi-Final                       Aston Villa              Everton           2
# Final                            Aston Villa     Newcastle United           2
#
#                          away_score  year qualifier replay  stage       date  \
# round
# Extra Preliminary Round           0  1905      True   True      1   14.09.04
# Preliminary Round                 0  1905      True   True      2   24.09.04
# First Qualifying Round            2  1905      True   True      3   10.10.04
# Second Qualifying Round           4  1905      True   True      4   22.10.04
# Third Qualifying Round            2  1905      True   True      5   07.11.04
# Fourth Qualifying Round           0  1905      True   True      6   23.11.04
# Fifth Qualifying Round            2  1905      True   True      7   07.12.04
# Intermediate Round                1  1905     False   True      8   23.01.05
# Sixth Qualifying Round            2  1905      True   True      9   15.12.04
# First Round Proper                0  1905     False   True     10   13.02.05
# Second Round Proper               0  1905     False   True     11   23.02.05
# Third Round Proper                0  1905     False   True     12   09.03.05
# Semi-Final                        1  1905     False   True     13   29.03.05
# Final                             0  1905     False  False     14  15-Apr-05
#
#                             match_id     round_id  year_id  \
# round
# Extra Preliminary Round  21199.00000  10959.00000    71267
# Preliminary Round        21250.00000  10966.00000    71267
# First Qualifying Round   21324.00000  10962.00000    71267
# Second Qualifying Round  21369.00000  10967.00000    71267
# Third Qualifying Round   21414.00000  10971.00000    71267
# Fourth Qualifying Round  21447.00000  10964.00000    71267
# Fifth Qualifying Round   21461.00000  10960.00000    71267
# Intermediate Round       21489.00000  10965.00000    71267
# Sixth Qualifying Round   21472.00000  10970.00000    71267
# First Round Proper       21513.00000  10963.00000    71267
# Second Round Proper      21524.00000  10968.00000    71267
# Third Round Proper       21529.00000  10972.00000    71267
# Semi-Final               21532.00000  10969.00000    71267
# Final                        0.00027      0.00027    71267
#
#                                         team  home  stage_r
# round
# Extra Preliminary Round     Thornhill United  True        1
# Preliminary Round             Stanley United  True        2
# First Qualifying Round                Druids  True        3
# Second Qualifying Round          Kensal Rise  True        4
# Third Qualifying Round   Wellingborough Town  True        5
# Fourth Qualifying Round     Stockport County  True        6
# Fifth Qualifying Round       Bishop Auckland  True        7
# Intermediate Round         Manchester United  True        8
# Sixth Qualifying Round     Burslem Port Vale  True        9
# First Round Proper                    Fulham  True       10
# Second Round Proper        Preston North End  True       11
# Third Round Proper       Sheffield Wednesday  True       12
# Semi-Final                       Aston Villa  True       13
# Final                            Aston Villa  True       14

# %% [markdown]
# The dates show us that the intermediate and 6th qualifying stages are in wrong order (also on data source). Will now check if any other intermediate stages are affected.

# %%
fac2[fac2['round'] == 'Intermediate Round'].groupby('year').first()
# Out:
#               home_team          away_team  home_score  away_score  \
# year
# 1901            Reading       Bristol City           2           1
# 1902     Bristol Rovers  Millwall Athletic           1           0
# 1903  Millwall Athletic     Bristol Rovers           2           0
# 1904  Manchester United        Small Heath           3           1
# 1905  Manchester United             Fulham           0           1
#
#                    round qualifier replay  stage      date  match_id  \
# year
# 1901  Intermediate Round     False   True      7  14.01.01     20292
# 1902  Intermediate Round     False   True      7  18.12.01     20570
# 1903  Intermediate Round     False   True      7  22.12.02     20847
# 1904  Intermediate Round     False   True      8  11.01.04     21149
# 1905  Intermediate Round     False   True      8  23.01.05     21489
#
#       round_id  year_id               team  home  stage_r
# year
# 1901     10915    71263            Reading  True        9
# 1902     10927    71264     Bristol Rovers  True        9
# 1903     10939    71265  Millwall Athletic  True        9
# 1904     10952    71266  Manchester United  True        9
# 1905     10965    71267  Manchester United  True        8

# %%
fac2[(fac2.year == 1901)].groupby('round').first().sort_values('stage')
# Out:
#                                     home_team             away_team  \
# round
# Preliminary Round                 Leytonstone              Woodford
# First Qualifying Round       Burton Wanderers               Gresley
# Second Qualifying Round  Maidstone United (1)         Sittingbourne
# Third Qualifying Round           Lincoln City  Gainsborough Trinity
# Fourth Qualifying Round               Clapton               Chatham
# Fifth Qualifying Round                Clapton       West Ham United
# Intermediate Round                    Reading          Bristol City
# First Round Proper                    Burnley          Newton Heath
# Second Round Proper         Nottingham Forest           Aston Villa
# Third Round Proper                Aston Villa           Small Heath
# Semi-Final                   Sheffield United           Aston Villa
# Final                       Tottenham Hotspur      Sheffield United
#
#                          home_score  away_score  year qualifier replay  stage  \
# round
# Preliminary Round                 1          10  1901      True   True      1
# First Qualifying Round            2           4  1901      True   True      2
# Second Qualifying Round           2           0  1901      True   True      3
# Third Qualifying Round            3           1  1901      True   True      4
# Fourth Qualifying Round           5           1  1901      True   True      5
# Fifth Qualifying Round            2           3  1901      True   True      6
# Intermediate Round                2           1  1901     False   True      7
# First Round Proper                7           1  1901     False   True      8
# Second Round Proper               1           3  1901     False   True      9
# Third Round Proper                1           0  1901     False   True     10
# Semi-Final                        3           0  1901     False   True     11
# Final                             3           1  1901     False   True     12
#
#                              date  match_id  round_id  year_id  \
# round
# Preliminary Round        27.09.00     20087     10916    71263
# First Qualifying Round   15.10.00     20149     10912    71263
# Second Qualifying Round  29.10.00     20196     10917    71263
# Third Qualifying Round   12.11.00     20244     10920    71263
# Fourth Qualifying Round  21.11.00     20266     10914    71263
# Fifth Qualifying Round   12.12.00     20280     10910    71263
# Intermediate Round       14.01.01     20292     10915    71263
# First Round Proper       13.02.01     20309     10913    71263
# Second Round Proper      27.02.01     20321     10918    71263
# Third Round Proper       27.03.01     20326     10921    71263
# Semi-Final               11.04.01     20330     10919    71263
# Final                    27.04.01     20332     10911    71263
#
#                                          team  home  stage_r
# round
# Preliminary Round                 Leytonstone  True        3
# First Qualifying Round       Burton Wanderers  True        4
# Second Qualifying Round  Maidstone United (1)  True        5
# Third Qualifying Round           Lincoln City  True        6
# Fourth Qualifying Round               Clapton  True        7
# Fifth Qualifying Round                Clapton  True        8
# Intermediate Round                    Reading  True        9
# First Round Proper                    Burnley  True       10
# Second Round Proper         Nottingham Forest  True       11
# Third Round Proper                Aston Villa  True       12
# Semi-Final                   Sheffield United  True       13
# Final                       Tottenham Hotspur  True       14

# %% [markdown]
# Modified above code for each year, only 1905 incorrect, need to fix now

# %%
fac2.loc[(fac2['year'] == 1905) & (fac2['round'] == 'Intermediate Round'), 'stage'] = 9
fac2.loc[(fac2['year'] == 1905) & (fac2['round'] == 'Sixth Qualifying Round'), 'stage'] = 8

# %%
fac2[(fac2.year == 1905)].groupby('round').first().sort_values('stage')
# Out:
#                                    home_team            away_team  home_score  \
# round
# Extra Preliminary Round     Thornhill United       Rotherham Town           1
# Preliminary Round             Stanley United        Leadgate Park           1
# First Qualifying Round                Druids      Oswestry United           3
# Second Qualifying Round          Kensal Rise        Civil Service           4
# Third Qualifying Round   Wellingborough Town       Kettering Town           1
# Fourth Qualifying Round     Stockport County              Glossop           1
# Fifth Qualifying Round       Bishop Auckland  Sunderland West End           1
# Sixth Qualifying Round     Burslem Port Vale             Barnsley           1
# Intermediate Round         Manchester United               Fulham           0
# First Round Proper                    Fulham              Reading           1
# Second Round Proper        Preston North End         Bristol City           1
# Third Round Proper       Sheffield Wednesday    Preston North End           3
# Semi-Final                       Aston Villa              Everton           2
# Final                            Aston Villa     Newcastle United           2
#
#                          away_score  year qualifier replay  stage       date  \
# round
# Extra Preliminary Round           0  1905      True   True      1   14.09.04
# Preliminary Round                 0  1905      True   True      2   24.09.04
# First Qualifying Round            2  1905      True   True      3   10.10.04
# Second Qualifying Round           4  1905      True   True      4   22.10.04
# Third Qualifying Round            2  1905      True   True      5   07.11.04
# Fourth Qualifying Round           0  1905      True   True      6   23.11.04
# Fifth Qualifying Round            2  1905      True   True      7   07.12.04
# Sixth Qualifying Round            2  1905      True   True      8   15.12.04
# Intermediate Round                1  1905     False   True      9   23.01.05
# First Round Proper                0  1905     False   True     10   13.02.05
# Second Round Proper               0  1905     False   True     11   23.02.05
# Third Round Proper                0  1905     False   True     12   09.03.05
# Semi-Final                        1  1905     False   True     13   29.03.05
# Final                             0  1905     False  False     14  15-Apr-05
#
#                             match_id     round_id  year_id  \
# round
# Extra Preliminary Round  21199.00000  10959.00000    71267
# Preliminary Round        21250.00000  10966.00000    71267
# First Qualifying Round   21324.00000  10962.00000    71267
# Second Qualifying Round  21369.00000  10967.00000    71267
# Third Qualifying Round   21414.00000  10971.00000    71267
# Fourth Qualifying Round  21447.00000  10964.00000    71267
# Fifth Qualifying Round   21461.00000  10960.00000    71267
# Sixth Qualifying Round   21472.00000  10970.00000    71267
# Intermediate Round       21489.00000  10965.00000    71267
# First Round Proper       21513.00000  10963.00000    71267
# Second Round Proper      21524.00000  10968.00000    71267
# Third Round Proper       21529.00000  10972.00000    71267
# Semi-Final               21532.00000  10969.00000    71267
# Final                        0.00027      0.00027    71267
#
#                                         team  home  stage_r
# round
# Extra Preliminary Round     Thornhill United  True        1
# Preliminary Round             Stanley United  True        2
# First Qualifying Round                Druids  True        3
# Second Qualifying Round          Kensal Rise  True        4
# Third Qualifying Round   Wellingborough Town  True        5
# Fourth Qualifying Round     Stockport County  True        6
# Fifth Qualifying Round       Bishop Auckland  True        7
# Sixth Qualifying Round     Burslem Port Vale  True        9
# Intermediate Round         Manchester United  True        8
# First Round Proper                    Fulham  True       10
# Second Round Proper        Preston North End  True       11
# Third Round Proper       Sheffield Wednesday  True       12
# Semi-Final                       Aston Villa  True       13
# Final                            Aston Villa  True       14

# %%
fac2.to_csv('facup_v3.csv', index = False)

# %%
#re-creating new column 'stage_r that 'hangs' stages off final (=14) rather than initial round

def set_stages(grp):
    stages = grp['stage'].max()
    grp['stage_r'] = grp['stage'] - stages + 14
    return grp

fac3 = fac2.groupby(['year']).apply(set_stages)

# %%
fac3[(fac3.year == 1905)].groupby('round').first().sort_values('stage')
# Out:
#                                    home_team            away_team  home_score  \
# round
# Extra Preliminary Round     Thornhill United       Rotherham Town           1
# Preliminary Round             Stanley United        Leadgate Park           1
# First Qualifying Round                Druids      Oswestry United           3
# Second Qualifying Round          Kensal Rise        Civil Service           4
# Third Qualifying Round   Wellingborough Town       Kettering Town           1
# Fourth Qualifying Round     Stockport County              Glossop           1
# Fifth Qualifying Round       Bishop Auckland  Sunderland West End           1
# Sixth Qualifying Round     Burslem Port Vale             Barnsley           1
# Intermediate Round         Manchester United               Fulham           0
# First Round Proper                    Fulham              Reading           1
# Second Round Proper        Preston North End         Bristol City           1
# Third Round Proper       Sheffield Wednesday    Preston North End           3
# Semi-Final                       Aston Villa              Everton           2
# Final                            Aston Villa     Newcastle United           2
#
#                          away_score  year qualifier replay  stage       date  \
# round
# Extra Preliminary Round           0  1905      True   True      1   14.09.04
# Preliminary Round                 0  1905      True   True      2   24.09.04
# First Qualifying Round            2  1905      True   True      3   10.10.04
# Second Qualifying Round           4  1905      True   True      4   22.10.04
# Third Qualifying Round            2  1905      True   True      5   07.11.04
# Fourth Qualifying Round           0  1905      True   True      6   23.11.04
# Fifth Qualifying Round            2  1905      True   True      7   07.12.04
# Sixth Qualifying Round            2  1905      True   True      8   15.12.04
# Intermediate Round                1  1905     False   True      9   23.01.05
# First Round Proper                0  1905     False   True     10   13.02.05
# Second Round Proper               0  1905     False   True     11   23.02.05
# Third Round Proper                0  1905     False   True     12   09.03.05
# Semi-Final                        1  1905     False   True     13   29.03.05
# Final                             0  1905     False  False     14  15-Apr-05
#
#                             match_id     round_id  year_id  \
# round
# Extra Preliminary Round  21199.00000  10959.00000    71267
# Preliminary Round        21250.00000  10966.00000    71267
# First Qualifying Round   21324.00000  10962.00000    71267
# Second Qualifying Round  21369.00000  10967.00000    71267
# Third Qualifying Round   21414.00000  10971.00000    71267
# Fourth Qualifying Round  21447.00000  10964.00000    71267
# Fifth Qualifying Round   21461.00000  10960.00000    71267
# Sixth Qualifying Round   21472.00000  10970.00000    71267
# Intermediate Round       21489.00000  10965.00000    71267
# First Round Proper       21513.00000  10963.00000    71267
# Second Round Proper      21524.00000  10968.00000    71267
# Third Round Proper       21529.00000  10972.00000    71267
# Semi-Final               21532.00000  10969.00000    71267
# Final                        0.00027      0.00027    71267
#
#                                         team  home  stage_r
# round
# Extra Preliminary Round     Thornhill United  True        1
# Preliminary Round             Stanley United  True        2
# First Qualifying Round                Druids  True        3
# Second Qualifying Round          Kensal Rise  True        4
# Third Qualifying Round   Wellingborough Town  True        5
# Fourth Qualifying Round     Stockport County  True        6
# Fifth Qualifying Round       Bishop Auckland  True        7
# Sixth Qualifying Round     Burslem Port Vale  True        8
# Intermediate Round         Manchester United  True        9
# First Round Proper                    Fulham  True       10
# Second Round Proper        Preston North End  True       11
# Third Round Proper       Sheffield Wednesday  True       12
# Semi-Final                       Aston Villa  True       13
# Final                            Aston Villa  True       14

# %%
nq3 = fac3[fac3['qualifier'] == False]

# %%
matches_per_stage = nq3.groupby(['year', 'stage_r'])['match_id'].nunique().unstack().reindex(range(1872,2016))

matches_per_stage.loc[1905]
# Out:
# stage_r
# 7    NaN
# 8    NaN
# 9     15
# 10    25
# 11    10
# 12     5
# 13     3
# 14     1
# Name: 1905, dtype: float64

# %%
ax = matches_per_stage.plot(kind='bar', 
                       figsize=(13,5), 
                       width=1, 
                       stacked=True, 
                       colormap = 'Blues_r')

ticks = ax.xaxis.get_ticklocs()
ticklabels = [l.get_text() for l in ax.xaxis.get_ticklabels()]
ax.xaxis.set_ticks(ticks[::5])
ax.xaxis.set_ticklabels(ticklabels[::5])
ax.legend().set_visible(False)

plt.show()
