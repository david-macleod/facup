# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('facup_v3.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137076 entries, 0 to 137075
# Data columns (total 16 columns):
# home_team     137076 non-null object
# away_team     137076 non-null object
# home_score    137076 non-null int64
# away_score    137076 non-null int64
# round         137076 non-null object
# year          137076 non-null int64
# qualifier     137076 non-null bool
# replay        137076 non-null bool
# stage         137076 non-null int64
# date          137076 non-null object
# match_id      137076 non-null float64
# round_id      137076 non-null float64
# year_id       137076 non-null int64
# team          137076 non-null object
# home          137076 non-null bool
# stage_r       137076 non-null int64
# dtypes: bool(3), float64(2), int64(6), object(5)
# memory usage: 15.0+ MB

# %%
unq = df.team.unique()

# %%
unq.size
# Out:
# 3434

# %%
df.team = df['team'].str.upper()

# %%
df.team
# Out:
# 0                ROYAL ENGINEERS
# 1                      WANDERERS
# 2         QUEEN'S PARK (GLASGOW)
# 3                ROYAL ENGINEERS
# 4                      WANDERERS
# 5                ROYAL ENGINEERS
# 6                      WANDERERS
# 7              OXFORD UNIVERSITY
# 8         QUEEN'S PARK (GLASGOW)
# 9                      WANDERERS
# 10                    MAIDENHEAD
# 11             OXFORD UNIVERSITY
# 12        QUEEN'S PARK (GLASGOW)
# 13                     WANDERERS
# 14             WINDSOR HOME PARK
# 15             1ST SURREY RIFLES
# 16                CLAPHAM ROVERS
# 17                 SOUTH NORWOOD
# 18        QUEEN'S PARK (GLASGOW)
# 19               ROYAL ENGINEERS
# 20                     WANDERERS
# 21                       HITCHIN
# 22            HAMPSTEAD HEATHENS
# 23                        BARNES
# 24            CRYSTAL PALACE (1)
# 25                     WANDERERS
# 26        QUEEN'S PARK (GLASGOW)
# 27                        BARNES
# ...

# %%
df.team.unique()
# Out:
# array(['ROYAL ENGINEERS', 'WANDERERS', "QUEEN'S PARK (GLASGOW)", ...,
#        'HARROWBY UNITED', 'HAYWARDS HEATH TOWN', 'HYTHE & DIBDEN'], dtype=object)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import difflib
# Out:
# C:\Users\David\Anaconda2\lib\site-packages\fuzzywuzzy\fuzz.py:33: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df['name_ratio'] = df.apply(lambda x: fuzz.ratio(x['team'], x['team']), axis=1)

# %%
fuzz.ratio('jade','jdeade')
# Out:
# 80

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ser = pd.Series(['hello','hola','hoppy'])

# %%
ser
# Out:
# 0    hello
# 1     hola
# 2    hoppy
# dtype: object

# %%
pd.crosstab(ser, ser)
# Out:
# col_0  hello  hola  hoppy
# row_0
# hello      1     0      0
# hola       0     1      0
# hoppy      0     0      1

# %%
unq = list(df.team.unique())

# %%
unq
# Out:
# ['ROYAL ENGINEERS',
#  'WANDERERS',
#  "QUEEN'S PARK (GLASGOW)",
#  'OXFORD UNIVERSITY',
#  'MAIDENHEAD',
#  'WINDSOR HOME PARK',
#  '1ST SURREY RIFLES',
#  'CLAPHAM ROVERS',
#  'SOUTH NORWOOD',
#  'HITCHIN',
#  'HAMPSTEAD HEATHENS',
#  'BARNES',
#  'CRYSTAL PALACE (1)',
#  'UPTON PARK',
#  'CIVIL SERVICE',
#  'REIGATE PRIORY',
#  'SHEFFIELD',
#  'SWIFTS',
#  'SHROPSHIRE WANDERERS',
#  'UXBRIDGE',
#  'CAMBRIDGE UNIVERSITY',
#  'WOODFORD WELLS',
#  'MARLOW',
#  'HIGH WYCOMBE',
#  'TROJANS',
#  'LEYTON',
#  'OLD ETONIANS',
#  'SOUTHALL',
#  'PILGRIMS',
#  '105TH REGIMENT',
#  'HERTS RANGERS',
#  'PANTHERS',
#  'ROCHESTER',
#  'FOREST SCHOOL',
#  'OLD HARROVIANS',
#  'REMNANTS',
#  'DRUIDS',
#  'DARWEN',
#  'READING',
#  'HAWKS',
#  'NOTTS COUNTY',
#  'GRANTHAM TOWN',
#  'OLD FORESTERS',
#  'NOTTINGHAM FOREST',
#  'HENDON (1)',
#  'ARGONAUTS',
#  'ACTON',
#  'FINCHLEY',
#  'GREY FRIARS',
#  'HOTSPUR',
#  'STAFFORD ROAD',
#  'BLACKBURN ROVERS',
#  'EAGLEY',
#  'GRESHAM',
#  'MOSQUITOS',
# ...

# %%
# %time fz =  process.extract('Manchester Utd', unq, limit = 2)
# Out:
# Wall time: 1.54 s

# %%
fz[0][0]
# Out:
# 'MANCHESTER'

# %%
process.extractOne('Man Utd', unq)
# Out:
# ('PARKGATE & RAWMARSH UTD.', 86)

# %%
df2 = df[0:10]

# %%
def nearest(df):
    match = process.extract(df['team'], unq, limit = 2)
    return match[1][0],match[1][1]

df2.apply(nearest, axis=1)
# Out:
# 0    (ROYAL ENGINEERS UNITED, 95)
# 1      (SHROPSHIRE WANDERERS, 90)
# 2                (UPTON PARK, 86)
# 3    (ROYAL ENGINEERS UNITED, 95)
# 4      (SHROPSHIRE WANDERERS, 90)
# 5    (ROYAL ENGINEERS UNITED, 95)
# 6      (SHROPSHIRE WANDERERS, 90)
# 7               (OXFORD CITY, 86)
# 8                (UPTON PARK, 86)
# 9      (SHROPSHIRE WANDERERS, 90)
# dtype: object

# %%
df2[['team', 'match']].head()
# Out:
#                      team                   match
# 0         ROYAL ENGINEERS  ROYAL ENGINEERS UNITED
# 1               WANDERERS    SHROPSHIRE WANDERERS
# 2  QUEEN'S PARK (GLASGOW)              UPTON PARK
# 3         ROYAL ENGINEERS  ROYAL ENGINEERS UNITED
# 4               WANDERERS    SHROPSHIRE WANDERERS

# %%
def nearest(df):
    match = process.extract(df, unq, limit = 2)
    return match[1][0],match[1][1]

print nearest('hello')
# Out:
# ('SHELL (ELLESMERE PORT)', 76)

# %%
a, b = nearest('open')

# %%
a
# Out:
# 'RYHOPE CA'

# %%
b
# Out:
# 74
