# %%
import pandas as pd
import numpy as np

import plotly
import plotly.plotly as py
import cufflinks as cf

# %%
nl_fac = pd.read_csv(r'C:\Users\David\Python\scrapy\facup\02_merge\nleague_teams_v1.csv')
nl_tab = pd.read_csv(r'C:\Users\David\Python\scrapy\facup\01_league_tables\nonleague_1990-11_v2.csv')

# %%
# restricting missing teams to range of scraped tables

nl_fac = nl_fac[nl_fac.year.isin(range(1990,2012))]

# %%
nl_fac.describe()
# Out:
#               year  stage
# count   703.000000    703
# mean   2000.512091      8
# std       6.345203      0
# min    1990.000000      8
# 25%    1995.000000      8
# 50%    2001.000000      8
# 75%    2006.000000      8
# max    2011.000000      8

# %%
nl_tab.describe()
# Out:
#                pos         year
# count  5054.000000  5054.000000
# mean     11.468540  2000.896320
# std       6.354594     6.444018
# min       1.000000  1990.000000
# 25%       6.000000  1995.000000
# 50%      11.000000  2001.000000
# 75%      17.000000  2007.000000
# max      24.000000  2011.000000

# %% [markdown]
# #### Merge test 1

# %%
nl_merge = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

# %% [markdown]
# #### Plotting missing matches, should be 32 matches per year

# %%
missing_teams = nl_merge[nl_merge.pos.isnull()].copy()

mt_plot = missing_teams.year.value_counts().sort_index().reindex()

# %%
mt_plot.iplot(kind='bar', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/965.embed" height="400px" width="700px"></iframe>

# %% [markdown]
# #### Apply fuzzy string matching to try and find near matches

# %%
from fuzzywuzzy import process
import fuzzywuzzy
import Levenshtein

# %%
def near_match(row):
    return process.extractOne(row['team'], nl_tab[nl_tab.year == row['year']]['team'].values) # only search specific year
     #return tuple containing (nearest match, score)
    
# %time missing_teams['match'], missing_teams['score'] = zip(*missing_teams.apply(near_match, axis = 1))
# Out:
# Wall time: 3.36 s

# %%
missing_teams[missing_teams.score > 94].sort_values('score')
# Out:
#                             team  pos  pts  year league               round  \
# 594                  FARNBOROUGH  NaN  NaN  1990    NaN  FIRST ROUND PROPER
# 691              FC HALIFAX TOWN  NaN  NaN  2008    NaN  FIRST ROUND PROPER
# 684              FC HALIFAX TOWN  NaN  NaN  2006    NaN  FIRST ROUND PROPER
# 678              FC HALIFAX TOWN  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 674                  FORD UNITED  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 673                  FARNBOROUGH  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 666               RUNCORN HALTON  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 664                  FARNBOROUGH  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 661                  FARNBOROUGH  NaN  NaN  2002    NaN  FIRST ROUND PROPER
# 655   HAMPTON & RICHMOND BOROUGH  NaN  NaN  2001    NaN  FIRST ROUND PROPER
# 639                  FARNBOROUGH  NaN  NaN  1998    NaN  FIRST ROUND PROPER
# 632                  FARNBOROUGH  NaN  NaN  1997    NaN  FIRST ROUND PROPER
# 625                  FARNBOROUGH  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 620              FC HALIFAX TOWN  NaN  NaN  1995    NaN  FIRST ROUND PROPER
# 617              FC HALIFAX TOWN  NaN  NaN  1994    NaN  FIRST ROUND PROPER
# 616                  FARNBOROUGH  NaN  NaN  1994    NaN  FIRST ROUND PROPER
# 604                  FARNBOROUGH  NaN  NaN  1992    NaN  FIRST ROUND PROPER
# 598                  FARNBOROUGH  NaN  NaN  1991    NaN  FIRST ROUND PROPER
# 644                  FORD UNITED  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 689                 KING'S LYNN_  NaN  NaN  2007    NaN  FIRST ROUND PROPER
# 700      FC UNITED OF MANCHESTER  NaN  NaN  2011    NaN  FIRST ROUND PROPER
# 692  HARROGATE RAILWAY ATHLETIC_  NaN  NaN  2008    NaN  FIRST ROUND PROPER
#
#      stage                       match  score
# 594      8            FARNBOROUGH TOWN     95
# 691      8                HALIFAX TOWN     95
# 684      8                HALIFAX TOWN     95
# 678      8                HALIFAX TOWN     95
# 674      8            FORD UNITED F.C.     95
# 673      8            FARNBOROUGH TOWN     95
# 666      8         RUNCORN F.C. HALTON     95
# 664      8            FARNBOROUGH TOWN     95
# 661      8            FARNBOROUGH TOWN     95
# 655      8          HAMPTON & RICHMOND     95
# 639      8            FARNBOROUGH TOWN     95
# 632      8            FARNBOROUGH TOWN     95
# 625      8            FARNBOROUGH TOWN     95
# 620      8                HALIFAX TOWN     95
# 617      8                HALIFAX TOWN     95
# 616      8            FARNBOROUGH TOWN     95
# 604      8            FARNBOROUGH TOWN     95
# 598      8            FARNBOROUGH TOWN     95
# 644      8            FORD UNITED F.C.     95
# 689      8                 KING'S LYNN     96
# 700      8   F.C. UNITED OF MANCHESTER     96
# 692      8  HARROGATE RAILWAY ATHLETIC     98

# %% [markdown]
# These matches are all correct

# %%
missing_teams[missing_teams.score.isin(range(88, 95))].sort_values('score')
# Out:
#                          team  pos  pts  year league               round  \
# 614                V.S. RUGBY  NaN  NaN  1993    NaN  FIRST ROUND PROPER
# 619                V.S. RUGBY  NaN  NaN  1994    NaN  FIRST ROUND PROPER
# 595    HAYES & YEADING UNITED  NaN  NaN  1990    NaN  FIRST ROUND PROPER
# 662    HAYES & YEADING UNITED  NaN  NaN  2002    NaN  FIRST ROUND PROPER
# 663                   CHESTER  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 668                 STEVENAGE  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 670  VAUXHALL MOTORS(W CHESH)  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 671                   CHESTER  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 676                 STEVENAGE  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 679    HAYES & YEADING UNITED  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 681                 STEVENAGE  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 682  VAUXHALL MOTORS(W CHESH)  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 688                 STEVENAGE  NaN  NaN  2006    NaN  FIRST ROUND PROPER
# 690                 STEVENAGE  NaN  NaN  2007    NaN  FIRST ROUND PROPER
# 693                 STEVENAGE  NaN  NaN  2008    NaN  FIRST ROUND PROPER
# 694            AFC HORNCHURCH  NaN  NaN  2009    NaN  FIRST ROUND PROPER
# 697                 STEVENAGE  NaN  NaN  2009    NaN  FIRST ROUND PROPER
# 656    HAYES & YEADING UNITED  NaN  NaN  2001    NaN  FIRST ROUND PROPER
# 653                   CHESTER  NaN  NaN  2001    NaN  FIRST ROUND PROPER
# 650    HAYES & YEADING UNITED  NaN  NaN  2000    NaN  FIRST ROUND PROPER
# 648                 STEVENAGE  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 599    HAYES & YEADING UNITED  NaN  NaN  1991    NaN  FIRST ROUND PROPER
# 600        LITTLEHAMPTON TOWN  NaN  NaN  1991    NaN  FIRST ROUND PROPER
# 606    HAYES & YEADING UNITED  NaN  NaN  1992    NaN  FIRST ROUND PROPER
# 610    HAYES & YEADING UNITED  NaN  NaN  1993    NaN  FIRST ROUND PROPER
# 621                   GRESLEY  NaN  NaN  1995    NaN  FIRST ROUND PROPER
# 622             NEWPORT (IOW)  NaN  NaN  1995    NaN  FIRST ROUND PROPER
# 627             NEWPORT (IOW)  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 626    HAYES & YEADING UNITED  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 633    HAYES & YEADING UNITED  NaN  NaN  1997    NaN  FIRST ROUND PROPER
# 636                 STEVENAGE  NaN  NaN  1997    NaN  FIRST ROUND PROPER
# 640    HAYES & YEADING UNITED  NaN  NaN  1998    NaN  FIRST ROUND PROPER
# 641                 STEVENAGE  NaN  NaN  1998    NaN  FIRST ROUND PROPER
# 645                   GRESLEY  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 646    HAYES & YEADING UNITED  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 629                 STEVENAGE  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 699                 STEVENAGE  NaN  NaN  2010    NaN  FIRST ROUND PROPER
# 698        AFC TELFORD UNITED  NaN  NaN  2010    NaN  FIRST ROUND PROPER
# 695        AFC TELFORD UNITED  NaN  NaN  2009    NaN  FIRST ROUND PROPER
#
#      stage                  match  score
# 614      8               VS RUGBY     89
# 619      8               VS RUGBY     89
# 595      8                  HAYES     90
# 662      8                  HAYES     90
# 663      8        DORCHESTER TOWN     90
# 668      8      STEVENAGE BOROUGH     90
# 670      8        VAUXHALL MOTORS     90
# 671      8        DORCHESTER TOWN     90
# 676      8      STEVENAGE BOROUGH     90
# 679      8                  HAYES     90
# 681      8      STEVENAGE BOROUGH     90
# 682      8        VAUXHALL MOTORS     90
# 688      8      STEVENAGE BOROUGH     90
# 690      8      STEVENAGE BOROUGH     90
# 693      8      STEVENAGE BOROUGH     90
# 694      8      A.F.C. HORNCHURCH     90
# 697      8      STEVENAGE BOROUGH     90
# 656      8                  HAYES     90
# 653      8        DORCHESTER TOWN     90
# 650      8                  HAYES     90
# 648      8      STEVENAGE BOROUGH     90
# 599      8                  HAYES     90
# 600      8                HAMPTON     90
# 606      8                  HAYES     90
# 610      8                  HAYES     90
# 621      8         GRESLEY ROVERS     90
# 622      8                NEWPORT     90
# 627      8                NEWPORT     90
# 626      8                  HAYES     90
# 633      8                  HAYES     90
# 636      8      STEVENAGE BOROUGH     90
# 640      8                  HAYES     90
# 641      8      STEVENAGE BOROUGH     90
# 645      8         GRESLEY ROVERS     90
# 646      8                  HAYES     90
# 629      8      STEVENAGE BOROUGH     90
# 699      8      STEVENAGE BOROUGH     90
# 698      8  A.F.C. TELFORD UNITED     92
# 695      8  A.F.C. TELFORD UNITED     92

# %%
# making list of teams with incorrect fuzzy match to avoid 

no_match = ['DORCHESTER TOWN', 'HAMPTON']

# %%
miss_88 = missing_teams[(missing_teams.score.isin(range(88, 95))) & ~(missing_teams.team.isin(no_match))]

# %%
miss_88
# Out:
#                          team  pos  pts  year league               round  \
# 595    HAYES & YEADING UNITED  NaN  NaN  1990    NaN  FIRST ROUND PROPER
# 599    HAYES & YEADING UNITED  NaN  NaN  1991    NaN  FIRST ROUND PROPER
# 600        LITTLEHAMPTON TOWN  NaN  NaN  1991    NaN  FIRST ROUND PROPER
# 606    HAYES & YEADING UNITED  NaN  NaN  1992    NaN  FIRST ROUND PROPER
# 610    HAYES & YEADING UNITED  NaN  NaN  1993    NaN  FIRST ROUND PROPER
# 614                V.S. RUGBY  NaN  NaN  1993    NaN  FIRST ROUND PROPER
# 619                V.S. RUGBY  NaN  NaN  1994    NaN  FIRST ROUND PROPER
# 621                   GRESLEY  NaN  NaN  1995    NaN  FIRST ROUND PROPER
# 622             NEWPORT (IOW)  NaN  NaN  1995    NaN  FIRST ROUND PROPER
# 626    HAYES & YEADING UNITED  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 627             NEWPORT (IOW)  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 629                 STEVENAGE  NaN  NaN  1996    NaN  FIRST ROUND PROPER
# 633    HAYES & YEADING UNITED  NaN  NaN  1997    NaN  FIRST ROUND PROPER
# 636                 STEVENAGE  NaN  NaN  1997    NaN  FIRST ROUND PROPER
# 640    HAYES & YEADING UNITED  NaN  NaN  1998    NaN  FIRST ROUND PROPER
# 641                 STEVENAGE  NaN  NaN  1998    NaN  FIRST ROUND PROPER
# 645                   GRESLEY  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 646    HAYES & YEADING UNITED  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 648                 STEVENAGE  NaN  NaN  1999    NaN  FIRST ROUND PROPER
# 650    HAYES & YEADING UNITED  NaN  NaN  2000    NaN  FIRST ROUND PROPER
# 653                   CHESTER  NaN  NaN  2001    NaN  FIRST ROUND PROPER
# 656    HAYES & YEADING UNITED  NaN  NaN  2001    NaN  FIRST ROUND PROPER
# 662    HAYES & YEADING UNITED  NaN  NaN  2002    NaN  FIRST ROUND PROPER
# 663                   CHESTER  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 668                 STEVENAGE  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 670  VAUXHALL MOTORS(W CHESH)  NaN  NaN  2003    NaN  FIRST ROUND PROPER
# 671                   CHESTER  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 676                 STEVENAGE  NaN  NaN  2004    NaN  FIRST ROUND PROPER
# 679    HAYES & YEADING UNITED  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 681                 STEVENAGE  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 682  VAUXHALL MOTORS(W CHESH)  NaN  NaN  2005    NaN  FIRST ROUND PROPER
# 688                 STEVENAGE  NaN  NaN  2006    NaN  FIRST ROUND PROPER
# 690                 STEVENAGE  NaN  NaN  2007    NaN  FIRST ROUND PROPER
# 693                 STEVENAGE  NaN  NaN  2008    NaN  FIRST ROUND PROPER
# 694            AFC HORNCHURCH  NaN  NaN  2009    NaN  FIRST ROUND PROPER
# 695        AFC TELFORD UNITED  NaN  NaN  2009    NaN  FIRST ROUND PROPER
# 697                 STEVENAGE  NaN  NaN  2009    NaN  FIRST ROUND PROPER
# 698        AFC TELFORD UNITED  NaN  NaN  2010    NaN  FIRST ROUND PROPER
# 699                 STEVENAGE  NaN  NaN  2010    NaN  FIRST ROUND PROPER
#
#      stage                  match  score
# 595      8                  HAYES     90
# 599      8                  HAYES     90
# 600      8                HAMPTON     90
# 606      8                  HAYES     90
# 610      8                  HAYES     90
# 614      8               VS RUGBY     89
# 619      8               VS RUGBY     89
# 621      8         GRESLEY ROVERS     90
# 622      8                NEWPORT     90
# 626      8                  HAYES     90
# 627      8                NEWPORT     90
# 629      8      STEVENAGE BOROUGH     90
# 633      8                  HAYES     90
# 636      8      STEVENAGE BOROUGH     90
# 640      8                  HAYES     90
# 641      8      STEVENAGE BOROUGH     90
# 645      8         GRESLEY ROVERS     90
# 646      8                  HAYES     90
# 648      8      STEVENAGE BOROUGH     90
# 650      8                  HAYES     90
# 653      8        DORCHESTER TOWN     90
# 656      8                  HAYES     90
# 662      8                  HAYES     90
# 663      8        DORCHESTER TOWN     90
# 668      8      STEVENAGE BOROUGH     90
# 670      8        VAUXHALL MOTORS     90
# 671      8        DORCHESTER TOWN     90
# 676      8      STEVENAGE BOROUGH     90
# 679      8                  HAYES     90
# 681      8      STEVENAGE BOROUGH     90
# 682      8        VAUXHALL MOTORS     90
# 688      8      STEVENAGE BOROUGH     90
# 690      8      STEVENAGE BOROUGH     90
# 693      8      STEVENAGE BOROUGH     90
# 694      8      A.F.C. HORNCHURCH     90
# 695      8  A.F.C. TELFORD UNITED     92
# 697      8      STEVENAGE BOROUGH     90
# 698      8  A.F.C. TELFORD UNITED     92
# 699      8      STEVENAGE BOROUGH     90
