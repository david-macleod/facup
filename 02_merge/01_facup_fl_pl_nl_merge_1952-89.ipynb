# %%
import pandas as pd
import numpy as np
import plotly
import plotly.plotly as py
import cufflinks as cf

# %%
nl_fac = pd.read_csv(r'C:\Users\David\Python\scrapy\facup\02_merge\nleague_teams_v1.csv')
nl_tab = pd.read_csv(r'C:\Users\David\Python\scrapy\facup\01_league_tables\nonleague_1952-89_v3.csv')

# %%
# restricting missing teams to range of scraped tables

nl_fac = nl_fac[nl_fac.year < 1990]

# %%
nl_fac.head()
# Out:
#                team  year               round  stage
# 0  AYLESBURY UNITED  1952  FIRST ROUND PROPER      8
# 1       BANGOR CITY  1952  FIRST ROUND PROPER      8
# 2   BARNSTAPLE TOWN  1952  FIRST ROUND PROPER      8
# 3        BARRY TOWN  1952  FIRST ROUND PROPER      8
# 4      BEDFORD TOWN  1952  FIRST ROUND PROPER      8

# %%
nl_tab.head()
# Out:
#    year  pos           league        team
# 0  1952    1  ATHENIAN LEAGUE  WEALDSTONE
# 1  1952    2  ATHENIAN LEAGUE      HENDON
# 2  1952    3  ATHENIAN LEAGUE     BROMLEY
# 3  1952    4  ATHENIAN LEAGUE   SUTTON U.
# 4  1952    5  ATHENIAN LEAGUE       HAYES

# %%
nl_fac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1216 entries, 0 to 1215
# Data columns (total 4 columns):
# team     1216 non-null object
# year     1216 non-null int64
# round    1216 non-null object
# stage    1216 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 47.5+ KB

# %%
nl_tab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32533 entries, 0 to 32532
# Data columns (total 4 columns):
# year      32533 non-null int64
# pos       32533 non-null int64
# league    32533 non-null object
# team      32533 non-null object
# dtypes: int64(2), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# ####  Merge test 1

# %%
nl_merge = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

# %% [markdown]
# #### Plotting missing matches, should be 32 matches per year

# %%
missing_teams = nl_merge[nl_merge.pos.isnull()].copy()

# %%
mt_plot = missing_teams.year.value_counts().sort_index().reindex()

# %%
mt_plot.iplot(kind='bar', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/928.embed" height="400px" width="700px"></iframe>

# %%
missing_teams = missing_teams[missing_teams.year < 1990]

# %% [markdown]
# #### Only 1962 has 32 matches, apply fuzzy string matching to try and find near matches

# %%
from fuzzywuzzy import process
import fuzzywuzzy
import Levenshtein

# %%
def near_match(row):
    return process.extractOne(row['team'], nl_tab[nl_tab.year == row['year']]['team'].values) # only search specific year
     #return tuple containing (nearest match, score)
    
# %time missing_teams['match'], missing_teams['score'] = zip(*missing_teams.apply(near_match, axis = 1))
# Out:
# Wall time: 19.6 s

# %%
missing_teams[missing_teams.score > 90].sort_values('score')
# Out:
#       year  pos league                      team               round  stage  \
# 1260  1953  NaN    NaN       PETERBOROUGH UNITED  FIRST ROUND PROPER      8
# 1262  1953  NaN    NaN        WALTHAMSTOW AVENUE  FIRST ROUND PROPER      8
# 1279  1954  NaN    NaN       PETERBOROUGH UNITED  FIRST ROUND PROPER      8
# 1281  1954  NaN    NaN        WALTHAMSTOW AVENUE  FIRST ROUND PROPER      8
# 1298  1955  NaN    NaN        WALTHAMSTOW AVENUE  FIRST ROUND PROPER      8
# 1377  1976  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1373  1975  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1383  1978  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1387  1979  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1328  1964  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1391  1980  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1376  1975  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1386  1978  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1393  1980  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
# 1402  1982  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1408  1984  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1411  1985  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1413  1985  NaN    NaN               KING'S LYNN  FIRST ROUND PROPER      8
# 1417  1985  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1418  1985  NaN    NaN            WINDSOR & ETON  FIRST ROUND PROPER      8
# 1419  1986  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1399  1981  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1382  1977  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1254  1953  NaN    NaN           HEREFORD UNITED  FIRST ROUND PROPER      8
# 1422  1987  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1255  1953  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1256  1953  NaN    NaN    KIDDERMINSTER HARRIERS  FIRST ROUND PROPER      8
# 1264  1953  NaN    NaN               YEOVIL TOWN  FIRST ROUND PROPER      8
# 1272  1954  NaN    NaN           HEREFORD UNITED  FIRST ROUND PROPER      8
# 1274  1954  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1283  1954  NaN    NaN               YEOVIL TOWN  FIRST ROUND PROPER      8
# 1380  1976  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1291  1955  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1307  1957  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1316  1961  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1332  1965  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1360  1972  NaN    NaN          BASINGSTOKE TOWN  FIRST ROUND PROPER      8
# 1426  1988  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1397  1981  NaN    NaN  ADDLESTONE & WEYBRIDGE T  FIRST ROUND PROPER      8
# 1352  1969  NaN    NaN            ST ALBANS CITY  FIRST ROUND PROPER      8
# 1401  1982  NaN    NaN           DORCHESTER TOWN  FIRST ROUND PROPER      8
# 1403  1982  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
# 1404  1982  NaN    NaN                   MOSSLEY  FIRST ROUND PROPER      8
# 1406  1982  NaN    NaN                WORKINGTON  FIRST ROUND PROPER      8
# 1321  1963  NaN    NaN                      RHYL  FIRST ROUND PROPER      8
# 1400  1982  NaN    NaN              BEDFORD TOWN  FIRST ROUND PROPER      8
#
#                             match  score
# 1260            PETERBOROUGH UTD.     91
# 1262             WALTHAMSTOW AVE.     91
# 1279            PETERBOROUGH UTD.     91
# 1281             WALTHAMSTOW AVE.     91
# 1298             WALTHAMSTOW AVE.     91
# 1377              A.P. LEAMINGTON     93
# 1373              A.P. LEAMINGTON     93
# 1383              A.P. LEAMINGTON     93
# 1387              A.P. LEAMINGTON     93
# 1328       TOOTING & MITCHAM UTD.     93
# 1391              A.P. LEAMINGTON     93
# 1376        TOOTING & MITCHAM UTD     93
# 1386   TOOTING AND MITCHAM UNITED     95
# 1393         LEYTONSTONE & ILFORD     95
# 1402                  HORDEN C.W.     95
# 1408             FARNBOROUGH TOWN     95
# 1411             FARNBOROUGH TOWN     95
# 1413                   KINGS LYNN     95
# 1417                    V.S.RUGBY     95
# 1418             WINDSOR AND ETON     95
# 1419             FARNBOROUGH TOWN     95
# 1399             FARNBOROUGH TOWN     95
# 1382            TOOTING & MITCHAM     95
# 1254         HEREFORD UNITED RES.     95
# 1422             FARNBOROUGH TOWN     95
# 1255                   HORDEN C.W     95
# 1256  KIDDERMINSTER HARRIERS RES.     95
# 1264             YEOVIL TOWN RES.     95
# 1272         HEREFORD UNITED RES.     95
# 1274                  HORDEN C.W.     95
# 1283             YEOVIL TOWN RES.     95
# 1380            TOOTING & MITCHAM     95
# 1291                   HORDEN C.W     95
# 1307            TOOTING & MITCHAM     95
# 1316                 MACCLESFIELD     95
# 1332                 MACCLESFIELD     95
# 1360                  BASINGSTOKE     95
# 1426             FARNBOROUGH TOWN     95
# 1397       ADDLESTONE & WEYBRIDGE     96
# 1352              ST. ALBANS CITY     97
# 1401             DORCHESTER TOWN.    100
# 1403           LEYTONSTONE-ILFORD    100
# 1404                     MOSSLEY.    100
# 1406                  WORKINGTON.    100
# 1321                        RHYL.    100
# 1400                BEDFORD TOWN.    100

# %% [markdown]
# Checking that no missing FA cup teams end with UTD. then then replacing UTD. with UNITED for non-league teams

# %%
nl_fac[nl_fac.team.str.contains('UTD\.$', regex=True)].team.unique()
# Out:
# array([], dtype=object)

# %%
nl_tab.team = nl_tab.team.str.replace('UTD\.$', 'UNITED')

# %% [markdown]
# Checking that no missing FA cup teams end with AVE. then then replacing AVE. with AVENUE for non-league teams

# %%
nl_fac[nl_fac.team.str.contains('AVE\.$', regex=True)].team.unique()
# Out:
# array([], dtype=object)

# %%
nl_tab.team = nl_tab.team.str.replace('AVE\.$', 'AVENUE')

# %% [markdown]
# Checking that no missing FA cup teams end . then then replacing . with '' for non-league teams

# %%
nl_fac[nl_fac.team.str.contains('\.$', regex=True)].team.unique()
# Out:
# array([], dtype=object)

# %%
nl_tab.team = nl_tab.team.str.replace('\.$', '')

# %% [markdown]
# #### Merge test 2

# %%
nl_merge2 = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

# %%
missing_teams2 = nl_merge2[nl_merge2.pos.isnull()].copy()

# %%
mt_plot2 = missing_teams2.year.value_counts().sort_index().reindex()

# %%
#making dataframe which join missing teams from 1st and 2nd merge

mt_plot_join = pd.DataFrame({'mt_plot':mt_plot, 'mt_plot2':mt_plot2})

mt_plot_join.iplot(kind='bar', barmode='overlay', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/930.embed" height="400px" width="700px"></iframe>

# %%
# %time missing_teams2['match'], missing_teams2['score'] = zip(*missing_teams2.apply(near_match, axis = 1))

missing_teams2[missing_teams2.score > 90].sort_values('score')
# Out:
# Wall time: 17.2 s
#       year  pos league                      team               round  stage  \
# 1391  1978  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1384  1975  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1381  1975  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1395  1979  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1399  1980  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1385  1976  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1394  1978  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1401  1980  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
# 1270  1953  NaN    NaN           HEREFORD UNITED  FIRST ROUND PROPER      8
# 1412  1984  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1415  1985  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1417  1985  NaN    NaN               KING'S LYNN  FIRST ROUND PROPER      8
# 1421  1985  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1422  1985  NaN    NaN            WINDSOR & ETON  FIRST ROUND PROPER      8
# 1423  1986  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1408  1982  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1407  1981  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1390  1977  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1388  1976  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1271  1953  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1272  1953  NaN    NaN    KIDDERMINSTER HARRIERS  FIRST ROUND PROPER      8
# 1278  1953  NaN    NaN               YEOVIL TOWN  FIRST ROUND PROPER      8
# 1286  1954  NaN    NaN           HEREFORD UNITED  FIRST ROUND PROPER      8
# 1288  1954  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1294  1954  NaN    NaN               YEOVIL TOWN  FIRST ROUND PROPER      8
# 1426  1987  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1430  1988  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1317  1957  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1326  1961  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1340  1965  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1368  1972  NaN    NaN          BASINGSTOKE TOWN  FIRST ROUND PROPER      8
# 1302  1955  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1405  1981  NaN    NaN  ADDLESTONE & WEYBRIDGE T  FIRST ROUND PROPER      8
# 1360  1969  NaN    NaN            ST ALBANS CITY  FIRST ROUND PROPER      8
# 1409  1982  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
#
#                            match  score
# 1391             A.P. LEAMINGTON     93
# 1384       TOOTING & MITCHAM UTD     93
# 1381             A.P. LEAMINGTON     93
# 1395             A.P. LEAMINGTON     93
# 1399             A.P. LEAMINGTON     93
# 1385             A.P. LEAMINGTON     93
# 1394  TOOTING AND MITCHAM UNITED     95
# 1401        LEYTONSTONE & ILFORD     95
# 1270         HEREFORD UNITED RES     95
# 1412            FARNBOROUGH TOWN     95
# 1415            FARNBOROUGH TOWN     95
# 1417                  KINGS LYNN     95
# 1421                   V.S.RUGBY     95
# 1422            WINDSOR AND ETON     95
# 1423            FARNBOROUGH TOWN     95
# 1408                  HORDEN C.W     95
# 1407            FARNBOROUGH TOWN     95
# 1390           TOOTING & MITCHAM     95
# 1388           TOOTING & MITCHAM     95
# 1271                  HORDEN C.W     95
# 1272  KIDDERMINSTER HARRIERS RES     95
# 1278             YEOVIL TOWN RES     95
# 1286         HEREFORD UNITED RES     95
# 1288                  HORDEN C.W     95
# 1294             YEOVIL TOWN RES     95
# 1426            FARNBOROUGH TOWN     95
# 1430            FARNBOROUGH TOWN     95
# 1317           TOOTING & MITCHAM     95
# 1326                MACCLESFIELD     95
# 1340                MACCLESFIELD     95
# 1368                 BASINGSTOKE     95
# 1302                  HORDEN C.W     95
# 1405      ADDLESTONE & WEYBRIDGE     96
# 1360             ST. ALBANS CITY     97
# 1409          LEYTONSTONE-ILFORD    100

# %% [markdown]
# #### Checking for reserve leagues

# %% [markdown]
# Want to drop any leagues with RES in the title and reserve teams cannot qualify for FA Cup
#
# First finding any current matches that are matched to a team from a reserve league and don't have multiple matches
#
# i.e. any team where there is a reserve team matched but we have no match for the first team

# %%
nl_merge2.groupby(['year', 'team']).filter(lambda x: (len(x) < 2) & (x['league'].str.contains('RES', regex=True)).any())
# Out:
#       year  pos                                             league  \
# 1151  1986    2  RESERVE TEAM FOOTBALL - ESSEX & HERTS BORDER C...
#
#                 team               round  stage
# 1151  LEYTON-WINGATE  FIRST ROUND PROPER      8

# %%
nl_tab[(nl_tab.team.str.contains('LEYTON')) & (nl_tab.year == 1986)]
# Out:
#        year  pos                                             league  \
# 23516  1986    6                         ISTHMIAN LEAGUE DIVISION 1
# 23522  1986   12                         ISTHMIAN LEAGUE DIVISION 1
# 24251  1986   11  THE OLD BOYS AMATEUR FOOTBALL LEAGUE SENIOR DI...
# 24292  1986    2  RESERVE TEAM FOOTBALL - ESSEX & HERTS BORDER C...
#
#                        team
# 23516        LEYTON WINGATE
# 23522  LEYTONSTONE & ILFORD
# 24251     LEYTON COUNTY O.B
# 24292        LEYTON-WINGATE

# %% [markdown]
# It should be safe to drop ALL reserve leagues as real LEYTON-WINGATE team exists in ISTHMIAN league and match will be made later
#
# First extracting the strings containing RES in the league names to check they all refer to reserve leagues

# %%
nl_tab.league.str.extract('(RES.*)').unique()
# Out:
# array([nan, 'RESERVE TEAM COMPETITION MIDDLESEX BORDER LEAGUE',
#        'RESERVE TEAM COMPETITIONS SUBURBAN LEAGUE NORTH',
#        'RESERVE TEAM COMPETITION SUBURBAN LEAGUE SOUTH',
#        'REST COMBINATION LEAGUE', 'RESERVES DIVISION 1',
#        'RESERVE TEAM FOOTBALL - ESSEX & HERTS BORDER COMBINATION EASTERN DIVISION',
#        'RESERVE TEAM FOOTBALL - ESSEX & HERTS BORDER COMBINATION WESTERN DIVISION',
#        'RESERVE TEAM FOOTBALL - MIDDLESEX BORDER COMBINATION',
#        'RESERVE TEAM FOOTBALL - SURBURBAN LEAGUE NORTH',
#        'RESERVE TEAM FOOTBALL - SURBURBAN LEAGUE SOUTH',
#        'RESERVE DIVISION', 'RESERVE TEAM FOOTBALL - SURBURBAN LEAGUE WEST',
#        'RESERVE DIVISION ONE', 'RESERVE DIVISION TWO'], dtype=object)

# %% [markdown]
# Need to preserve 'REST COMBINATION LEAGUE' by looking for 'RESERVE' rather than 'RES'

# %% [markdown]
# #### Dropping reserve leagues

# %%
nl_tab = nl_tab[~nl_tab.league.str.contains('RESERVE', regex=True)]

# %% [markdown]
# #### Checking for remaining 'reserve' teams

# %% [markdown]
# Now checking for teams containing RES in title in FA cup teams

# %%
nl_fac[nl_fac.team.str.contains(' RES', regex=True)]
# Out:
# Empty DataFrame
# Columns: [team, year, round, stage]
# Index: []

# %% [markdown]
# Now checking for teams containing RES in title in Non league tables

# %%
nl_tab.team.str.extract('( RES.*)').unique()
# Out:
# array([nan, ' RES', ' RESERVES', ' RESERVE', ' RESERBES', ' RESEARCH',
#        ' RESERVES OB'], dtype=object)

# %% [markdown]
# No FA cup teams contain RES (see above) so happy to drop RESEARCH also

# %% [markdown]
# #### Dropping reserve teams

# %%
nl_tab = nl_tab[~nl_tab.team.str.contains(' RES', regex=True)]

# %%
# %time missing_teams2['match'], missing_teams2['score'] = zip(*missing_teams2.apply(near_match, axis = 1))

missing_teams2[missing_teams2.score > 90].sort_values('score')
# Out:
# Wall time: 15.2 s
#       year  pos league                      team               round  stage  \
# 1381  1975  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1384  1975  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1385  1976  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1391  1978  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1399  1980  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1395  1979  NaN    NaN             AP LEAMINGTON  FIRST ROUND PROPER      8
# 1271  1953  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1423  1986  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1422  1985  NaN    NaN            WINDSOR & ETON  FIRST ROUND PROPER      8
# 1421  1985  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1417  1985  NaN    NaN               KING'S LYNN  FIRST ROUND PROPER      8
# 1415  1985  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1412  1984  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1408  1982  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1407  1981  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1401  1980  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
# 1394  1978  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1390  1977  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1388  1976  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1368  1972  NaN    NaN          BASINGSTOKE TOWN  FIRST ROUND PROPER      8
# 1340  1965  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1326  1961  NaN    NaN         MACCLESFIELD TOWN  FIRST ROUND PROPER      8
# 1317  1957  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1302  1955  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1288  1954  NaN    NaN                 HORDEN CW  FIRST ROUND PROPER      8
# 1426  1987  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1430  1988  NaN    NaN               FARNBOROUGH  FIRST ROUND PROPER      8
# 1405  1981  NaN    NaN  ADDLESTONE & WEYBRIDGE T  FIRST ROUND PROPER      8
# 1360  1969  NaN    NaN            ST ALBANS CITY  FIRST ROUND PROPER      8
# 1409  1982  NaN    NaN        LEYTONSTONE/ILFORD  FIRST ROUND PROPER      8
#
#                            match  score
# 1381             A.P. LEAMINGTON     93
# 1384       TOOTING & MITCHAM UTD     93
# 1385             A.P. LEAMINGTON     93
# 1391             A.P. LEAMINGTON     93
# 1399             A.P. LEAMINGTON     93
# 1395             A.P. LEAMINGTON     93
# 1271                  HORDEN C.W     95
# 1423            FARNBOROUGH TOWN     95
# 1422            WINDSOR AND ETON     95
# 1421                   V.S.RUGBY     95
# 1417                  KINGS LYNN     95
# 1415            FARNBOROUGH TOWN     95
# 1412            FARNBOROUGH TOWN     95
# 1408                  HORDEN C.W     95
# 1407            FARNBOROUGH TOWN     95
# 1401        LEYTONSTONE & ILFORD     95
# 1394  TOOTING AND MITCHAM UNITED     95
# 1390           TOOTING & MITCHAM     95
# 1388           TOOTING & MITCHAM     95
# 1368                 BASINGSTOKE     95
# 1340                MACCLESFIELD     95
# 1326                MACCLESFIELD     95
# 1317           TOOTING & MITCHAM     95
# 1302                  HORDEN C.W     95
# 1288                  HORDEN C.W     95
# 1426            FARNBOROUGH TOWN     95
# 1430            FARNBOROUGH TOWN     95
# 1405      ADDLESTONE & WEYBRIDGE     96
# 1360             ST. ALBANS CITY     97
# 1409          LEYTONSTONE-ILFORD    100

# %% [markdown]
# After dropping reserve teams I am happy that all the teams with near matches (>90) in this list are correct so creating a series to map the names in nl_tab to the actual names in nl_fac

# %%
miss_90 = missing_teams2[missing_teams2.score > 90].sort_values('score')

# %%
name_map1 = pd.Series(data=miss_90.team.values, index=miss_90.match.values)

name_map1
# Out:
# A.P. LEAMINGTON                          AP LEAMINGTON
# TOOTING & MITCHAM UTD         TOOTING & MITCHAM UNITED
# A.P. LEAMINGTON                          AP LEAMINGTON
# A.P. LEAMINGTON                          AP LEAMINGTON
# A.P. LEAMINGTON                          AP LEAMINGTON
# A.P. LEAMINGTON                          AP LEAMINGTON
# HORDEN C.W                                   HORDEN CW
# FARNBOROUGH TOWN                           FARNBOROUGH
# WINDSOR AND ETON                        WINDSOR & ETON
# V.S.RUGBY                                   V.S. RUGBY
# KINGS LYNN                                 KING'S LYNN
# FARNBOROUGH TOWN                           FARNBOROUGH
# FARNBOROUGH TOWN                           FARNBOROUGH
# HORDEN C.W                                   HORDEN CW
# FARNBOROUGH TOWN                           FARNBOROUGH
# LEYTONSTONE & ILFORD                LEYTONSTONE/ILFORD
# TOOTING AND MITCHAM UNITED    TOOTING & MITCHAM UNITED
# TOOTING & MITCHAM             TOOTING & MITCHAM UNITED
# TOOTING & MITCHAM             TOOTING & MITCHAM UNITED
# BASINGSTOKE                           BASINGSTOKE TOWN
# MACCLESFIELD                         MACCLESFIELD TOWN
# MACCLESFIELD                         MACCLESFIELD TOWN
# TOOTING & MITCHAM             TOOTING & MITCHAM UNITED
# HORDEN C.W                                   HORDEN CW
# HORDEN C.W                                   HORDEN CW
# FARNBOROUGH TOWN                           FARNBOROUGH
# FARNBOROUGH TOWN                           FARNBOROUGH
# ADDLESTONE & WEYBRIDGE        ADDLESTONE & WEYBRIDGE T
# ST. ALBANS CITY                         ST ALBANS CITY
# LEYTONSTONE-ILFORD                  LEYTONSTONE/ILFORD
# dtype: object

# %% [markdown]
# #### Updating team names in nl_tab

# %%
nl_tab.team.replace(to_replace=name_map1.index, value=name_map1.values, inplace=True)

# %% [markdown]
# #### Merge test 3

# %%
nl_merge3 = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

# %%
missing_teams3 = nl_merge3[nl_merge3.pos.isnull()].copy()

mt_plot3 = missing_teams3.year.value_counts().sort_index().reindex()

# %%
mt_plot_join['mt_plot3'] = mt_plot3

mt_plot_join.iplot(kind='bar', barmode='overlay', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/932.embed" height="400px" width="700px"></iframe>

# %%
# %time missing_teams3['match'], missing_teams3['score'] = zip(*missing_teams3.apply(near_match, axis = 1))


# widening fuzzy string match tolerance to above 88
missing_teams3[missing_teams3.score > 88].sort_values('score')
# Out:
# Wall time: 12.7 s
#       year  pos league                      team               round  stage  \
# 1306  1955  NaN    NaN    TUNBRIDGE WELLS UNITED  FIRST ROUND PROPER      8
# 1269  1953  NaN    NaN   BEIGHTON MINERS WELFARE  FIRST ROUND PROPER      8
# 1405  1988  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1296  1955  NaN    NaN           CHELMSFORD CITY  FIRST ROUND PROPER      8
# 1402  1987  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1399  1986  NaN    NaN                V.S. RUGBY  FIRST ROUND PROPER      8
# 1320  1959  NaN    NaN  TOOTING & MITCHAM UNITED  FIRST ROUND PROPER      8
# 1366  1973  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1365  1973  NaN    NaN                ALTON TOWN  FIRST ROUND PROPER      8
# 1359  1971  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1357  1970  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1263  1952  NaN    NaN      BILLINGHAM SYNTHONIA  FIRST ROUND PROPER      8
# 1367  1973  NaN    NaN    HAYES & YEADING UNITED  FIRST ROUND PROPER      8
# 1351  1968  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1345  1967  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1316  1958  NaN    NaN                CROOK TOWN  FIRST ROUND PROPER      8
# 1321  1961  NaN    NaN           CHICHESTER CITY  FIRST ROUND PROPER      8
# 1323  1962  NaN    NaN             GRANTHAM TOWN  FIRST ROUND PROPER      8
# 1327  1963  NaN    NaN                WELLINGTON  FIRST ROUND PROPER      8
# 1330  1964  NaN    NaN                FOLKESTONE  FIRST ROUND PROPER      8
# 1332  1964  NaN    NaN      NETHERFIELD (KENDAL)  FIRST ROUND PROPER      8
# 1299  1955  NaN    NaN           HASTINGS UNITED  FIRST ROUND PROPER      8
# 1409  1989  NaN    NaN            NEWPORT COUNTY  FIRST ROUND PROPER      8
# 1397  1986  NaN    NaN            LEYTON-WINGATE  FIRST ROUND PROPER      8
#
#                      match  score
# 1306     TUNBRIDGE WELLS U     89
# 1269     BEIGHTON MINERS W     89
# 1405              VS RUGBY     89
# 1296          CHELMSFORD C     89
# 1402              VS RUGBY     89
# 1399              VS RUGBY     89
# 1320   TOOTING & MITCHAM U     89
# 1366              GRANTHAM     90
# 1365            LUTON TOWN     90
# 1359              GRANTHAM     90
# 1357              GRANTHAM     90
# 1263            BILLINGHAM     90
# 1367                 HAYES     90
# 1351              GRANTHAM     90
# 1345              GRANTHAM     90
# 1344       FOLKESTONE TOWN     90
# 1354              GRANTHAM     90
# 1353             TONBRIDGE     90
# 1371              GRANTHAM     90
# 1341              GRANTHAM     90
# 1372                 HAYES     90
# 1376              GRANTHAM     90
# 1379             ARNOLD FC     90
# 1388                 FLEET     90
# 1390              HOLBEACH     90
# 1393       FISHER ATHLETIC     90
# 1394             BLUE STAR     90
# 1403               YEADING     90
# 1406       FISHER ATHLETIC     90
# 1369             TONBRIDGE     90
# 1339       FOLKESTONE TOWN     90
# 1335                 HAYES     90
# 1407               YEADING     90
# 1268             TONBRIDGE     90
# 1271              HEREFORD     90
# 1272         KIDDERMINSTER     90
# 1274           NETHERFIELD     90
# 1276             TONBRIDGE     90
# 1277       WELLINGTON TOWN     90
# 1278                YEOVIL     90
# 1280         CAMBRIDGE UTD     90
# 1284            HASTINGS U     90
# 1286            HEREFORD U     90
# 1292       WELLINGTON TOWN     90
# 1336           NETHERFIELD     90
# 1295         CAMBRIDGE UTD     90
# 1303           NETHERFIELD     90
# 1307       WELLINGTON TOWN     90
# 1309           NETHERFIELD     90
# 1311            BILLINGHAM     90
# 1315            BILLINGHAM     90
# 1316                 CROOK     90
# 1321               CHESTER     90
# 1323              GRANTHAM     90
# 1327  SANKEYS (WELLINGTON)     90
# 1330       FOLKESTONE TOWN     90
# 1332           NETHERFIELD     90
# 1299            HASTINGS U     90
# 1409               NEWPORT     90
# 1397        LEYTON WINGATE    100

# %% [markdown]
# Have checked each of the fuzzy matches is a legitmate match (e.g. checked other sources / dates on teams of similar name existing)
#
# The only ones in this list that are not matches properly are LUTON TOWN, FLEET, CHESTER and SANKEYS (WELLINGTON)

# %%
no_match = ['LUTON TOWN', 'FLEET', 'CHESTER', 'SANKEYS (WELLINGTON)']

miss_88 = missing_teams3[(missing_teams3.score > 88) & ~(missing_teams3.team.isin(no_match))]

# %%
name_map2 = pd.Series(data=miss_88.team.values, index=miss_88.match.values)

name_map2
# Out:
# BILLINGHAM                  BILLINGHAM SYNTHONIA
# TONBRIDGE                       TONBRIDGE ANGELS
# BEIGHTON MINERS W        BEIGHTON MINERS WELFARE
# HEREFORD                         HEREFORD UNITED
# KIDDERMINSTER             KIDDERMINSTER HARRIERS
# NETHERFIELD                 NETHERFIELD (KENDAL)
# TONBRIDGE                       TONBRIDGE ANGELS
# WELLINGTON TOWN                       WELLINGTON
# YEOVIL                               YEOVIL TOWN
# CAMBRIDGE UTD                   CAMBRIDGE UNITED
# HASTINGS U                       HASTINGS UNITED
# HEREFORD U                       HEREFORD UNITED
# WELLINGTON TOWN                       WELLINGTON
# CAMBRIDGE UTD                   CAMBRIDGE UNITED
# CHELMSFORD C                     CHELMSFORD CITY
# HASTINGS U                       HASTINGS UNITED
# NETHERFIELD                 NETHERFIELD (KENDAL)
# TUNBRIDGE WELLS U         TUNBRIDGE WELLS UNITED
# WELLINGTON TOWN                       WELLINGTON
# NETHERFIELD                 NETHERFIELD (KENDAL)
# BILLINGHAM                  BILLINGHAM SYNTHONIA
# BILLINGHAM                  BILLINGHAM SYNTHONIA
# CROOK                                 CROOK TOWN
# TOOTING & MITCHAM U     TOOTING & MITCHAM UNITED
# CHESTER                          CHICHESTER CITY
# GRANTHAM                           GRANTHAM TOWN
# SANKEYS (WELLINGTON)                  WELLINGTON
# FOLKESTONE TOWN                       FOLKESTONE
# NETHERFIELD                 NETHERFIELD (KENDAL)
# HAYES                     HAYES & YEADING UNITED
# NETHERFIELD                 NETHERFIELD (KENDAL)
# FOLKESTONE TOWN                       FOLKESTONE
# GRANTHAM                           GRANTHAM TOWN
# FOLKESTONE TOWN                       FOLKESTONE
# GRANTHAM                           GRANTHAM TOWN
# GRANTHAM                           GRANTHAM TOWN
# TONBRIDGE                       TONBRIDGE ANGELS
# GRANTHAM                           GRANTHAM TOWN
# GRANTHAM                           GRANTHAM TOWN
# GRANTHAM                           GRANTHAM TOWN
# LUTON TOWN                            ALTON TOWN
# GRANTHAM                           GRANTHAM TOWN
# HAYES                     HAYES & YEADING UNITED
# TONBRIDGE                       TONBRIDGE ANGELS
# GRANTHAM                           GRANTHAM TOWN
# HAYES                     HAYES & YEADING UNITED
# GRANTHAM                           GRANTHAM TOWN
# ARNOLD FC                                 ARNOLD
# FLEET                           EBBSFLEET UNITED
# HOLBEACH                         HOLBEACH UNITED
# FISHER ATHLETIC                           FISHER
# BLUE STAR                    NEWCASTLE BLUE STAR
# LEYTON WINGATE                    LEYTON-WINGATE
# VS RUGBY                              V.S. RUGBY
# VS RUGBY                              V.S. RUGBY
# YEADING                   HAYES & YEADING UNITED
# VS RUGBY                              V.S. RUGBY
# FISHER ATHLETIC                           FISHER
# YEADING                   HAYES & YEADING UNITED
# NEWPORT                           NEWPORT COUNTY
# dtype: object

# %% [markdown]
# #### Updating team names in nl_tab

# %%
nl_tab.team.replace(to_replace=name_map2.index, value=name_map2.values, inplace=True)

# %% [markdown]
# #### Merge test 4

# %%
nl_merge4 = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

missing_teams4 = nl_merge4[nl_merge4.pos.isnull()].copy()

mt_plot4 = missing_teams4.year.value_counts().sort_index().reindex()

# %%
mt_plot_join['mt_plot4'] = mt_plot4

mt_plot_join.iplot(kind='bar', barmode='overlay', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/934.embed" height="400px" width="700px"></iframe>

# %%
mt_plot.sum()
# Out:
# 188L

# %%
mt_plot4.sum()
# Out:
# 87L

# %% [markdown]
# Through regulariasation and fuzzy string matching with QC have found 100 extra matches :)
#
# Fuzzy matches below a score of 88 were quite erratic so returning multiple potential matches per team with new function

# %%
missing_teams4[missing_teams4.year == 1952]
# Out:
#       year  pos league                        team               round  stage
# 1335  1952  NaN    NaN  BLACKHALL COLLIERY WELFARE  FIRST ROUND PROPER      8
# 1336  1952  NaN    NaN                  FOLKESTONE  FIRST ROUND PROPER      8
# 1337  1952  NaN    NaN                MERTHYR TOWN  FIRST ROUND PROPER      8
# 1338  1952  NaN    NaN            RAWMARSH WELFARE  FIRST ROUND PROPER      8

# %% [markdown]
# Creating new string matching function that returns multiple matches

# %%
def near_matches(row):
    matches =  process.extract(row['team'], nl_tab[nl_tab.year == row['year']]['team'].values, limit = 3) # only search specific year
    # matches is list of tuples in form [('1st nearest match, 1st nearest match score), (2nd nearest match, 2nd nearest match score)]
    return matches

# %time missing_teams4['match1'], missing_teams4['match2'], missing_teams4['match3'] = zip(*missing_teams4.apply(near_matches, axis = 1))
# Out:
# Wall time: 7.22 s

# %%
missing_teams4
# Out:
#       year  pos league                        team               round  stage  \
# 1335  1952  NaN    NaN  BLACKHALL COLLIERY WELFARE  FIRST ROUND PROPER      8
# 1336  1952  NaN    NaN                  FOLKESTONE  FIRST ROUND PROPER      8
# 1337  1952  NaN    NaN                MERTHYR TOWN  FIRST ROUND PROPER      8
# 1338  1952  NaN    NaN            RAWMARSH WELFARE  FIRST ROUND PROPER      8
# 1339  1953  NaN    NaN         GREAT YARMOUTH TOWN  FIRST ROUND PROPER      8
# 1340  1953  NaN    NaN                    LLANELLI  FIRST ROUND PROPER      8
# 1341  1953  NaN    NaN               NEWPORT (IOW)  FIRST ROUND PROPER      8
# 1342  1954  NaN    NaN                BEDFORD TOWN  FIRST ROUND PROPER      8
# 1343  1954  NaN    NaN          FERRYHILL ATHLETIC  FIRST ROUND PROPER      8
# 1344  1954  NaN    NaN         GREAT YARMOUTH TOWN  FIRST ROUND PROPER      8
# 1345  1954  NaN    NaN              GUILDFORD CITY  FIRST ROUND PROPER      8
# 1346  1954  NaN    NaN           HEADINGTON UNITED  FIRST ROUND PROPER      8
# 1347  1954  NaN    NaN                HITCHIN TOWN  FIRST ROUND PROPER      8
# 1348  1954  NaN    NaN              KETTERING TOWN  FIRST ROUND PROPER      8
# 1349  1954  NaN    NaN                    LLANELLI  FIRST ROUND PROPER      8
# 1350  1954  NaN    NaN               NEWPORT (IOW)  FIRST ROUND PROPER      8
# 1351  1954  NaN    NaN               NUNEATON TOWN  FIRST ROUND PROPER      8
# 
# 1401        (NORTHWICH VICTORIA, 60)
# 1402              (TAUNTON TOWN, 80)
# 1403                  (LYE TOWN, 86)
# 1404  (MEXBOROUGH TOWN ATHLETIC, 86)
# 1405             (BOSTON UNITED, 69)
# 1406       (SAFFRON WALDEN TOWN, 86)
# 1407  (MEXBOROUGH TOWN ATHLETIC, 86)
# 1408                (EYE UNITED, 86)
# 1409       (SAFFRON WALDEN TOWN, 86)
# 1410    (CHESTER-LE-STREET TOWN, 86)
# 1411                    (MORRIS, 66)
# 1412  (WELLINGTON TOWN (DORSET), 86)
# 1413         (GAINSBOROUGH TOWN, 81)
# 1414           (GILLINGHAM TOWN, 86)
# 1415  (MEXBOROUGH TOWN ATHLETIC, 86)
# 1416               (FORD UNITED, 88)
# 1417      (BISHOPS WALTHAM TOWN, 86)
# 1418  (ASHFORD TOWN (MIDDLESEX), 86)
# 1419               (HENLEY TOWN, 64)
# 1420        (SOHAM TOWN RANGERS, 86)
# 1421      (WOOTTON BASSETT TOWN, 86)
#
# [87 rows x 9 columns]

# %% [markdown]
# There appears to be a lot of team names truncated to T where T = Town, C where C = City, U where U = United and Ath = Athletic
#
# Will check if there are any current matches we need to preserve and update the rest

# %%
nl_merge4[nl_merge4.team.str.contains(' T$', regex=True)]
# Out:
#       year  pos                            league                      team  \
# 1044  1981    9  SOUTHERN LEAGUE DIVISION 1 SOUTH  ADDLESTONE & WEYBRIDGE T
#
#                    round  stage
# 1044  FIRST ROUND PROPER      8

# %% [markdown]
# #### Checking and updating 'T'  teams

# %%
mask_T = ~((nl_tab.year == 1981) & (nl_tab.team == 'ADDLESTONE & WEYBRIDGE T'))

# %%
mask_T.value_counts()
# Out:
# True     30572
# False        1
# dtype: int64

# %%
nl_tab.ix[mask_T, 'team'] = nl_tab[mask_T].team.str.replace(' T$',' TOWN')

# %% [markdown]
# #### Checking and updating 'U'  teams

# %%
nl_merge4[nl_merge4.team.str.contains(' U$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [year, pos, league, team, round, stage]
# Index: []

# %%
nl_tab['team'] = nl_tab['team'].str.replace(' U$',' UNITED')

# %% [markdown]
# #### Checking and updating 'C'  teams

# %%
nl_merge4[nl_merge4.team.str.contains(' C$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [year, pos, league, team, round, stage]
# Index: []

# %%
nl_tab['team'] = nl_tab['team'].str.replace(' C$',' CITY')

# %% [markdown]
# #### Checking and updating 'ATH'  teams

# %%
nl_merge4[nl_merge4.team.str.contains(' ATH$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [year, pos, league, team, round, stage]
# Index: []

# %%
nl_tab['team'] = nl_tab['team'].str.replace(' ATH$',' ATHLETIC')

# %% [markdown]
# #### Merge test 5

# %%
nl_merge5 = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

missing_teams5 = nl_merge5[nl_merge5.pos.isnull()].copy()

mt_plot5 = missing_teams5.year.value_counts().sort_index().reindex()

# %%
mt_plot_join['mt_plot5'] = mt_plot5

mt_plot_join.iplot(kind='bar', barmode='overlay', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/942.embed" height="400px" width="700px"></iframe>

# %%
# %time missing_teams5['match1'], missing_teams5['match2'], missing_teams5['match3'] = zip(*missing_teams5.apply(near_matches, axis = 1))
# Out:
# Wall time: 6.02 s

# %% [markdown]
# Now exporting at finding and filling missing teams individually

# %%
missing_teams5.to_csv('missing_teams_1952-89_v1.csv', index = False)

# %% [markdown]
# All missing teams manually researched and updated (apart from RAWMARSH WELFARE, 1952. This will be added when found)

# %%
nl_tab_aux = pd.read_csv('missing_teams_1952-89_v2.csv')[['year', 'pos', 'league', 'team']]

nl_tab_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 0 to 74
# Data columns (total 4 columns):
# year      75 non-null int64
# pos       74 non-null float64
# league    74 non-null object
# team      75 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.9+ KB

# %%
nl_tab = pd.concat([nl_tab, nl_tab_aux])

# %% [markdown]
# #### Merge test 6

# %%
nl_merge6 = pd.merge(nl_tab, nl_fac, how='right', on=['team', 'year'])

missing_teams6 = nl_merge6[nl_merge6.pos.isnull()].copy()

mt_plot6 = missing_teams6.year.value_counts().sort_index().reindex()

# %%
mt_plot_join['mt_plot6'] = mt_plot6

mt_plot_join.iplot(kind='bar', barmode='overlay', dimensions = (700,400))
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~starhammer/944.embed" height="400px" width="700px"></iframe>

# %% [markdown]
# Now looking at teams that have multiple matches and keeping the correct one
#
# Teams will be kept preferentially from 'higher' leagues, that is NORTHERN, SOUTHERN, ISTHMIAN, CONFERENCE etc whilst the  duplicate team in a 'regional' league will be the reserve team not elligible for the FA Cup

# %%
dupe_match = nl_merge6.groupby(['year', 'team']).filter(lambda x: len(x) > 1)

dupe_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413 entries, 2 to 1346
# Data columns (total 6 columns):
# year      413 non-null int64
# pos       413 non-null float64
# league    413 non-null object
# team      413 non-null object
# round     413 non-null object
# stage     413 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 22.6+ KB

# %%
dupe_match.to_csv('dupe_match_1952-89_v1.csv', index = False)

# %%
de_duped = pd.read_csv('dupe_match_1952-89_v2.csv')

# %%
de_duped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203 entries, 0 to 202
# Data columns (total 6 columns):
# year      203 non-null int64
# pos       203 non-null int64
# league    203 non-null object
# team      203 non-null object
# round     203 non-null object
# stage     203 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 11.1+ KB

# %%
no_dupe = nl_merge6.groupby(['year', 'team']).filter(lambda x: len(x) == 1)

# %%
no_dupe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1013 entries, 0 to 1425
# Data columns (total 6 columns):
# year      1013 non-null int64
# pos       1012 non-null float64
# league    1012 non-null object
# team      1013 non-null object
# round     1013 non-null object
# stage     1013 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 55.4+ KB

# %%
de_duped.groupby(['year', 'team']).filter(lambda x: len(x) > 1)  #checking no duplicates were missed
# Out:
# Empty DataFrame
# Columns: [year, pos, league, team, round, stage]
# Index: []

# %%
fin_1952_89 = pd.concat([no_dupe, de_duped])

# %%
fin_1952_89.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1216 entries, 0 to 202
# Data columns (total 6 columns):
# year      1216 non-null int64
# pos       1215 non-null float64
# league    1215 non-null object
# team      1216 non-null object
# round     1216 non-null object
# stage     1216 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 66.5+ KB

# %% [markdown]
# #### Final save of non-league 1952-89 merge

# %%
fin_1952_89.to_csv(r'C:\Users\David\Python\scrapy\facup\01_league_tables\nonleague_1952-89_v4.csv', index=False)
